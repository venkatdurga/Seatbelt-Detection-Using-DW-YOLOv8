# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import numpy as np
import torchvision.transforms as T
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

class SeatbeltDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_dir = os.path.join(root_dir, 'images')
        self.label_dir = os.path.join(root_dir, 'labels')
        self.image_files = [f for f in os.listdir(self.image_dir) if f.endswith('.jpg')]

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_name = self.image_files[idx]
        img_path = os.path.join(self.image_dir, img_name)
        mask_path = img_path.replace('.jpg', '.npy')
        label_path = os.path.join(self.label_dir, img_name.replace('.jpg', '.txt'))

        # Load image
        image = Image.open(img_path).convert("RGB")

        # Load mask with default if not found
        if os.path.exists(mask_path):
            mask = np.load(mask_path)
            mask = torch.tensor(mask, dtype=torch.uint8)
        else:
            print(f"Warning: Mask file not found: {mask_path}. Using default mask.")
            mask = torch.zeros((1, *Image.open(img_path).size[::-1]), dtype=torch.uint8)  # Default mask with zeros

        # Load annotations
        boxes = []
        labels = []
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                for line in f.readlines():
                    parts = line.strip().split()
                    class_id = int(parts[0])
                    x_min = float(parts[1])
                    y_min = float(parts[2])
                    x_max = float(parts[3])
                    y_max = float(parts[4])
                    boxes.append([x_min, y_min, x_max, y_max])
                    labels.append(class_id)
        else:
            print(f"Warning: Label file not found: {label_path}. Skipping.")

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)

        # Validate boxes
        valid_boxes = []
        valid_labels = []
        for box, label in zip(boxes, labels):
            x_min, y_min, x_max, y_max = box
            if x_min < x_max and y_min < y_max:
                valid_boxes.append(box)
                valid_labels.append(label)
            else:
                print(f"Invalid box: {box}")

        if len(valid_boxes) == 0:
            valid_boxes = torch.empty((0, 4), dtype=torch.float32)
            valid_labels = torch.empty((0,), dtype=torch.int64)
        else:
            valid_boxes = torch.stack(valid_boxes, dim=0) if valid_boxes else torch.empty((0, 4), dtype=torch.float32)
            valid_labels = torch.tensor(valid_labels, dtype=torch.int64) if valid_labels else torch.empty((0,), dtype=torch.int64)

        target = {}
        target['boxes'] = valid_boxes
        target['labels'] = valid_labels
        target['masks'] = mask.unsqueeze(0)  # Add an extra dimension for the batch size

        if self.transform:
            image = self.transform(image)

        return image, target

transform = T.Compose([T.ToTensor()])

train_dataset = SeatbeltDataset('/content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train', transform=transform)
train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))

def get_model_instance_segmentation(num_classes):
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(weights='DEFAULT')

    # Get the number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # Replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # Get the number of input features for the mask classifier
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask, hidden_layer, num_classes)

    return model

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
num_classes = 2  # Background and seatbelt
model = get_model_instance_segmentation(num_classes)
model.to(device)

params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
num_epochs = 25

for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    for images, targets in train_dataloader:
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        optimizer.zero_grad()
        try:
            loss_dict = model(images, targets)
            losses = sum(loss for loss in loss_dict.values())
            losses.backward()
            optimizer.step()
            epoch_loss += losses.item()
        except Exception as e:
            print(f"Error during training: {e}")
            continue

    lr_scheduler.step()
    print(f"Epoch {epoch+1}, Loss: {epoch_loss}")

    # # Save model checkpoint
    # if (epoch + 1) % 5 == 0:
    #     torch.save(model.state_dict(), f'/content/drive/MyDrive/SeatBelt_model_epoch_{epoch+1}.pth')

# Save the final model
torch.save(model.state_dict(), '/content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt_model_final.pth')
# Out:
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__184_88_best_win_rider_jpg.rf.3c6420d2670d00519675002d672f98de.npy. Using default mask.
# Invalid box: tensor([0.3229, 0.3209, 0.3016, 0.3005])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__468_88_best_win_rider_jpg.rf.b4f0668f5a9f18e83c101d1db7988c63.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__595_88_best_win_rider_jpg.rf.47cc9ebe6c0eea4cae1acc15bf1c3564.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__531_88_best_win_rider_jpg.rf.2eb329fd8dda5d423642cc20246fcc01.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__607_84_best_win_rider_jpg.rf.b056c163586bc8cbb0ac7e72bd41137b.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__846_87_best_win_rider_jpg.rf.59d10b78be94ea63875b248787b25ed9.npy. Using default mask.
# Invalid box: tensor([0.2674, 0.3023, 0.2517, 0.3096])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__696_88_best_win_rider_jpg.rf.4348740e2aa53fbaeee3028af664b257.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__351_76_best_win_non_rider_jpg.rf.2739bcb0c0a53f4658c6a4a0d7926e22.npy. Using default mask.
# Invalid box: tensor([0.4943, 0.4055, 0.4876, 0.4077])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__322_84_best_win_non_rider_jpg.rf.a16399843a0c7d4cb376441342623841.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__639_91_best_win_non_rider_jpg.rf.039571e446cadcb0fc38e6468f17a348.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__880_86_best_win_rider_jpg.rf.2d3f5a088e671f1697c66a1de20a1764.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__523_84_best_win_rider_jpg.rf.52916089be94b8c55c05871bc19e0c56.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__744_89_best_win_non_rider_jpg.rf.b77f67b4ad8bff073a44cc7f95efe888.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__572_82_best_win_rider_jpg.rf.0515f125407bec752efac3a078f09954.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__984_86_best_win_rider_jpg.rf.a0373fd03d55c24e6759820b901f1512.npy. Using default mask.
# Invalid box: tensor([0.3856, 0.2719, 0.3276, 0.2991])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__510_87_best_win_rider_jpg.rf.71da0a937ceba13b8c63c815cec18f5d.npy. Using default mask.
# Invalid box: tensor([0.1927, 0.2317, 0.2140, 0.2174])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__700_87_best_win_rider_jpg.rf.a984c3bda36cecb28570a29bb7270d8e.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__786_87_best_win_rider_jpg.rf.23e63dce61d68e65f39ec43bca76b485.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__245_86_best_win_rider_jpg.rf.f40a940923b04cf82ea7beeaf8a9465e.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__369_86_best_win_rider_jpg.rf.d4fda17175f43e4a46aa8b820bd5618f.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__203_88_best_win_non_rider_jpg.rf.b9ee6b9842934a52b17684a49415a5e2.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__359_88_best_win_non_rider_jpg.rf.b82647bb528cb2ef221eb3a06b7c3972.npy. Using default mask.
# Invalid box: tensor([0.4611, 0.3783, 0.1952, 0.8507])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__840_89_best_win_rider_jpg.rf.ff2fd06492f6f15e137f0df98fddb840.npy. Using default mask.
# Invalid box: tensor([0.6715, 0.1467, 0.6026, 0.1469])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__974_89_best_win_rider_jpg.rf.ac23f067841e744fb9c988c59efa2769.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__869_88_best_win_non_rider_jpg.rf.3fa6eba5d49664f97a2b702140dbee64.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__207_89_best_win_non_rider_jpg.rf.dbc632d88541a12e791b241330a67ef0.npy. Using default mask.
# Invalid box: tensor([0.5917, 0.2097, 0.3382, 0.6052])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__663_89_best_win_rider_jpg.rf.4b9400380556713cffdccbf87e7f6f87.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__541_86_best_win_rider_jpg.rf.9a40c9999e209fab513e254f73a58957.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__388_86_best_win_rider_jpg.rf.5c0f3f62d6e27b9f83b0d1df754c5cab.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__444_88_best_win_rider_jpg.rf.f563252e38766b1fe97b9d34f76b35c8.npy. Using default mask.
# Invalid box: tensor([0.6514, 0.3459, 0.6000, 0.2968])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__628_89_best_win_rider_jpg.rf.d4f4045c0afc6fc19e938ed3bd48ef40.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__705_90_best_win_non_rider_jpg.rf.cf8fe7149d0696f4b03c1e2331527495.npy. Using default mask.
# Invalid box: tensor([0.5534, 0.3163, 0.3959, 0.5439])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__209_88_best_win_rider_jpg.rf.4bf400bd757e94f5fbd54ad74095604d.npy. Using default mask.
# Invalid box: tensor([0.3556, 0.2414, 0.3392, 0.2493])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__925_87_best_win_non_rider_jpg.rf.09caac438ef238fc40d0291817afb0a1.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__659_88_best_win_rider_jpg.rf.ab6ddef3378abd9e9a449f4f1e1993d5.npy. Using default mask.
# Invalid box: tensor([0.3678, 0.2355, 0.3224, 0.2550])
# Invalid box: tensor([0.4693, 0.3336, 0.1970, 0.7619])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__910_83_best_win_rider_jpg.rf.59bdfbf947113354cbec1b313a58d7ca.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__938_80_best_win_rider_jpg.rf.ac57f9b827aee56d24c5b4fa50be23a5.npy. Using default mask.
# Invalid box: tensor([0.6430, 0.2852, 0.3215, 0.7050])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__192_91_best_win_non_rider_jpg.rf.6f6845bc542b7622840dfda571965d78.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__340_86_best_win_non_rider_jpg.rf.c0dc36fd4720ecdd2b069c29dce9eba2.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__471_85_best_win_rider_jpg.rf.c28a7b08256a4870258abe87e2b91d02.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__491_88_best_win_non_rider_jpg.rf.d1a3b18bd20ce9f851ee6c3e201b3569.npy. Using default mask.
# Invalid box: tensor([0.6181, 0.1962, 0.3030, 0.7150])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__880_86_best_win_non_rider_jpg.rf.f8b372ac2473fffe66dcb030b21fc3c1.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__787_88_best_win_rider_jpg.rf.aa437df2bac9dc800bb4a028e595cb0e.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__258_88_best_win_non_rider_jpg.rf.bf516f5c9049a7fa8393777440e98fef.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__756_80_best_win_non_rider_jpg.rf.7cdf0acaa41089b9354318b4fc38454f.npy. Using default mask.
# Invalid box: tensor([0.4901, 0.2755, 0.2376, 0.6227])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__241_88_best_win_rider_jpg.rf.5b0824ed0cc0e1cdbd6a13eea86d35d3.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__746_81_best_win_rider_jpg.rf.716f899a09278caa1d3780c740e3a513.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__407_89_best_win_rider_jpg.rf.62923b4df21cb04feb17071b8f5b2eae.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__401_89_best_win_rider_jpg.rf.8820772720ff0a34528d8127af68ade1.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__920_88_best_win_non_rider_jpg.rf.03172b06f980c4b8816d93ded156b377.npy. Using default mask.
# Invalid box: tensor([0.6181, 0.2903, 0.2601, 0.9015])
# Invalid box: tensor([0.2912, 0.1397, 0.2729, 0.1381])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__221_85_best_win_non_rider_jpg.rf.2d8d0c274806fe6b953aea8d028d632b.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__621_81_best_win_non_rider_jpg.rf.a37fe3bf9eba486f6b4b68e4d7c057db.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__545_88_best_win_non_rider_jpg.rf.3632b076939ae73cb4e1e64fe80223fd.npy. Using default mask.
# Invalid box: tensor([0.5927, 0.3868, 0.3489, 0.7408])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__299_85_best_win_non_rider_jpg.rf.82d3d3045f2790f69f97e54a98ea261a.npy. Using default mask.
# Invalid box: tensor([0.5661, 0.3724, 0.3205, 0.6799])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__715_90_best_win_rider_jpg.rf.9adb1f0a2fcb4ca5cf07523e51ac4ff5.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__918_88_best_win_rider_jpg.rf.33a0f13399bf47e329bb26d6e7677307.npy. Using default mask.
# Invalid box: tensor([0.3867, 0.1760, 0.3484, 0.2159])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__465_86_best_win_non_rider_jpg.rf.34830f5387653ee26bd3500751a00f81.npy. Using default mask.
# Invalid box: tensor([0.7660, 0.1359, 0.5358, 0.4785])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__511_82_best_win_non_rider_jpg.rf.41427a12a45ede4a39f0a8a52e4f5428.npy. Using default mask.
# Invalid box: tensor([0.4478, 0.0000, 0.2170, 0.5202])
# Invalid box: tensor([0.4981, 0.5041, 0.6876, 0.1928])
# Invalid box: tensor([0.5345, 0.3747, 0.5295, 0.3712])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__381_83_best_win_rider_jpg.rf.506b34aa3dc8564a0132cf220fceac6c.npy. Using default mask.
# Invalid box: tensor([0.3021, 0.2493, 0.2866, 0.2478])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__634_84_best_win_rider_jpg.rf.211bc8a3ef38faa9306d054e77cfcca9.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__728_90_best_win_rider_jpg.rf.b5177e2e1cf638c41070257182109841.npy. Using default mask.
# Invalid box: tensor([0.3193, 0.2165, 0.3113, 0.2205])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__524_90_best_win_rider_jpg.rf.0fdc94204cd092b1287e2d9bf800318b.npy. Using default mask.
# Invalid box: tensor([0.5987, 0.3767, 0.4526, 0.5743])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__895_82_best_win_rider_jpg.rf.3352d0df74327bd813c15aa5149ce68f.npy. Using default mask.
# Invalid box: tensor([0.6726, 0.6101, 0.4593, 0.3116])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__863_86_best_win_non_rider_jpg.rf.68309356e33ef298a15dde3f60995649.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__900_87_best_win_non_rider_jpg.rf.1fa580530cb3c845b0ae50f7bda039b7.npy. Using default mask.
# Invalid box: tensor([0.5246, 0.2448, 0.2327, 0.6027])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__683_87_best_win_rider_jpg.rf.c8e820d348e1b4bba374e8205a0ad06b.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__537_90_best_win_non_rider_jpg.rf.f1a9c417a0a4de7f1c9eda64cb6f7580.npy. Using default mask.
# Invalid box: tensor([0.4407, 0.2986, 0.2256, 0.6739])
# Invalid box: tensor([0.4350, 0.4381, 0.4167, 0.4381])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__666_90_best_win_rider_jpg.rf.dbe791948528571943317e77e5641ec9.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__373_88_best_win_rider_jpg.rf.b87ce951a6d26f455698fd8ba1f732f8.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__533_87_best_win_rider_jpg.rf.847c77775d0faab5840a6771c220bc11.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__504_87_best_win_rider_jpg.rf.cd27f544a7338f3656dfa19e7650ab29.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__485_87_best_win_non_rider_jpg.rf.c17a9ed26297a731aee8ec9c19f634ed.npy. Using default mask.
# Invalid box: tensor([0.5840, 0.3409, 0.3705, 0.5761])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__868_89_best_win_non_rider_jpg.rf.1f897cbbfd56ccd46a5ca09446bf0e39.npy. Using default mask.
# Invalid box: tensor([0.5202, 0.4645, 0.3246, 0.8327])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__513_87_best_win_rider_jpg.rf.a83bb738c62979c6f504b9a3d0037e97.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__456_88_best_win_non_rider_jpg.rf.2103af65e097cfae1a884aee48a44e2c.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__552_88_best_win_non_rider_jpg.rf.6d1dc69f9b5f0d6c35526a829db1047e.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__423_89_best_win_rider_jpg.rf.088e206fde7d8e73df706445325987e6.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__195_90_best_win_rider_jpg.rf.6deaf1ba934bbdc387175542b3bd33c8.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__586_84_best_win_rider_jpg.rf.a1268d6647cd49aa40d19cc94ccaf3da.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__861_91_best_win_rider_jpg.rf.661ed597e5baff55f2b990758319308d.npy. Using default mask.
# Invalid box: tensor([0.2138, 0.2763, 0.2078, 0.2808])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__405_87_best_win_rider_jpg.rf.bae2095df0e22b243d43b9ec2f9752ec.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__855_90_best_win_rider_jpg.rf.2611dfb13ac8ff3946381b4306cb0646.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__417_85_best_win_rider_jpg.rf.f298ae714a03a64f674a9ac536650c15.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__509_87_best_win_non_rider_jpg.rf.f88cdf958491696a4775795ce9313aa8.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__858_90_best_win_non_rider_jpg.rf.f37a8d62aaac55b96b9329a832a0fa6e.npy. Using default mask.
# Invalid box: tensor([0.5219, 0.1908, 0.3036, 0.4230])
# Invalid box: tensor([0.5052, 0.0772, 0.2654, 0.3991])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__357_89_best_win_non_rider_jpg.rf.b2505582613153177b7ebb5e2f22ac95.npy. Using default mask.
# Invalid box: tensor([0.5828, 0.2909, 0.3151, 0.7080])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__922_88_best_win_rider_jpg.rf.b4c9ff9fc455b71000a5eb34b1571fe2.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__548_89_best_win_non_rider_jpg.rf.db63615cbe5a2a5b20a9534e49bf3007.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__675_87_best_win_non_rider_jpg.rf.d34250e0c518f620555bfd23264d7213.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__677_85_best_win_rider_jpg.rf.3a7402520812c9d694362ef6e7ac1dbf.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__696_88_best_win_non_rider_jpg.rf.6ae8ee6799c3ab2d5cf08fd292b6079a.npy. Using default mask.
# Invalid box: tensor([0.1979, 0.2288, 0.1813, 0.2310])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__466_88_best_win_rider_jpg.rf.e12b2b501051f9a2603c108100ec6442.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__798_87_best_win_rider_jpg.rf.b0264a9e1c9aac13b0ac9346d1e35d5a.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__815_87_best_win_rider_jpg.rf.826cfa5cf2d368147c89437aa19bc5e0.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__718_88_best_win_rider_jpg.rf.286a74189a1f71e86741a39262bbf40a.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__646_90_best_win_non_rider_jpg.rf.c63f42d8737ebb669085d32cb886a93a.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__611_87_best_win_non_rider_jpg.rf.06ffacb6be5dfb541a0c50665d2fa308.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__705_90_best_win_rider_jpg.rf.e8e91d1d067ea934f7e91a5b44a6febd.npy. Using default mask.
# Invalid box: tensor([0.2768, 0.1554, 0.2678, 0.1709])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__944_89_best_win_rider_jpg.rf.62a26d9a92c4716b065879843b55fd91.npy. Using default mask.
# Invalid box: tensor([0.4958, 0.3095, 0.2064, 0.8757])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__670_87_best_win_rider_jpg.rf.6bab76de834cba495a005cb2c81400b1.npy. Using default mask.
# Invalid box: tensor([0.2978, 0.1584, 0.2387, 0.1401])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__557_90_best_win_non_rider_jpg.rf.6b7821b9aa846794f0016d210f9d2ea4.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__330_87_best_win_non_rider_jpg.rf.740a78f28808308661cc8c509f737e53.npy. Using default mask.
# Invalid box: tensor([0.5328, 0.3006, 0.4427, 0.8199])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__736_85_best_win_rider_jpg.rf.ad333d575be95a72e10649b2d4fe9879.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__192_91_best_win_rider_jpg.rf.41375252d5758a58c3cdd815b039f12c.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__745_91_best_win_rider_jpg.rf.cb51a923fc9d27c25f444f1e314f1bb3.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__600_85_best_win_rider_jpg.rf.adf3859dee631244d6042ea82bf29440.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__657_85_best_win_rider_jpg.rf.3495e721a0b754ae757d1e0a191e660f.npy. Using default mask.
# Invalid box: tensor([0.3463, 0.1087, 0.3337, 0.1125])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__854_85_best_win_rider_jpg.rf.8d1a6623881f75c17b9e6e7b11c7a329.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__551_84_best_win_rider_jpg.rf.46d8bb35a274d265b9b7be37cd5a9158.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__464_86_best_win_non_rider_jpg.rf.a5e9778011251b510c42981b7acfc6ad.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__923_89_best_win_rider_jpg.rf.897695b0fcef85045be3d30d8bcdac38.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__276_88_best_win_non_rider_jpg.rf.1cd74a5ae6631979f8e8e57244d0896f.npy. Using default mask.
# Invalid box: tensor([0.2073, 0.3572, 0.1975, 0.3521])
# Invalid box: tensor([0.3037, 0.1886, 0.2792, 0.1851])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__731_87_best_win_rider_jpg.rf.577c33590db8e1197412e390f3a240c8.npy. Using default mask.
# Invalid box: tensor([0.3478, 0.2166, 0.2678, 0.2220])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__279_79_best_win_rider_jpg.rf.0afc467112f397bb621fd27b746124eb.npy. Using default mask.
# Invalid box: tensor([0.3455, 0.1268, 0.3015, 0.1926])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__234_89_best_win_rider_jpg.rf.e2a7db39401aa59a246939fdb0acd147.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__887_87_best_win_rider_jpg.rf.b2fd43c154aefeb7bbfcbfc496028408.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__941_87_best_win_rider_jpg.rf.7349380b22b6433e6fe0f6d937ed65a6.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__899_88_best_win_rider_jpg.rf.7ad1feba0a9d1825fe20882d62693135.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__672_86_best_win_rider_jpg.rf.e0348c4e39d7949a03dd0ffd68f4741b.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__585_89_best_win_non_rider_jpg.rf.2140f6fd2c1ce5a4406c6c68a39572a3.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__912_86_best_win_rider_jpg.rf.57080a0559458ea22c5335ce390ae6d5.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__850_88_best_win_rider_jpg.rf.b74e96522740a07a1b0ab505eeed43b8.npy. Using default mask.
# Invalid box: tensor([0.6995, 0.3443, 0.4308, 0.7184])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__768_77_best_win_rider_jpg.rf.34c486c691d73e019687785367963008.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__608_87_best_win_rider_jpg.rf.416bafd111fd4bfce3842719a84496ce.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__516_77_best_win_rider_jpg.rf.78cb261f56e0b97657512218d52141e0.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__446_89_best_win_rider_jpg.rf.0d82f14f343d6f4ebbc36a49b45f4a1f.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__784_88_best_win_non_rider_jpg.rf.9be2df332696d763fb89c292abbf67d4.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__558_87_best_win_non_rider_jpg.rf.6cb01c467d52394788e141d7d916cf60.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__370_90_best_win_non_rider_jpg.rf.8089c90810ae72fe9816adf34d395b89.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__649_88_best_win_rider_jpg.rf.93134091fec00e55678217dd24a01503.npy. Using default mask.
# Invalid box: tensor([0.6300, 0.2909, 0.6245, 0.3000])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__846_87_best_win_non_rider_jpg.rf.1169a151991cebc92d9fd8bb0b162545.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__448_90_best_win_non_rider_jpg.rf.f819aff0ea3903786d8250392d522303.npy. Using default mask.
# Invalid box: tensor([0.6707, 0.1462, 0.5438, 0.1469])
# Invalid box: tensor([0.2390, 0.2205, 0.2231, 0.2422])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__352_86_best_win_rider_jpg.rf.46b06b4ccb70c079131c5dffe08200ae.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__861_91_best_win_non_rider_jpg.rf.91ab30eeefe72eede68287ee99484bf0.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__298_89_best_win_non_rider_jpg.rf.fa314227d79332fc1feaa151bd45c451.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__935_90_best_win_rider_jpg.rf.2aa4ddd0c2b496265325bf4a76a4f7b7.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__858_90_best_win_rider_jpg.rf.f42b7ded4ddc198e3734bbbfe12010eb.npy. Using default mask.
# Invalid box: tensor([0.5759, 0.5249, 0.5571, 0.5267])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__959_90_best_win_rider_jpg.rf.cf3fd9993386431d7b04a095d02aaacb.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__711_90_best_win_non_rider_jpg.rf.f45d52e520d13883f02c98b12804dba9.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__915_82_best_win_non_rider_jpg.rf.f65480b9013a2d9ec4154ebd85dbdee2.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__223_89_best_win_rider_jpg.rf.4c3a158bc56b2ed6092d3621455a1689.npy. Using default mask.
# Invalid box: tensor([0.5832, 0.3730, 0.5350, 0.4557])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__418_87_best_win_non_rider_jpg.rf.a68998454d0a5437704426e59848399a.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__347_88_best_win_rider_jpg.rf.c2d8be02f6d8b95dcdde0102e6fc3175.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__797_83_best_win_non_rider_jpg.rf.4bfe42d56a867186bae865057bf22914.npy. Using default mask.
# Invalid box: tensor([0.2552, 0.2307, 0.2493, 0.2291])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__249_90_best_win_non_rider_jpg.rf.0b4af261424ed71534e0911d8e7c993e.npy. Using default mask.
# Invalid box: tensor([0.5264, 0.3306, 0.3328, 0.5924])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__704_88_best_win_non_rider_jpg.rf.22f79730e378d8d9852278a3703d4ead.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__222_90_best_win_rider_jpg.rf.d48cee55c98cfda97287bfddc3de48d1.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__807_87_best_win_non_rider_jpg.rf.e9d900d6e2672dffa674f11b527bfb71.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__229_90_best_win_non_rider_jpg.rf.5f17ef75e768f0cd67509b52a9e617bc.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__726_88_best_win_rider_jpg.rf.a7c594dc880530004c5d7db5552e341d.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__661_86_best_win_rider_jpg.rf.f8d11e46cbaa79fb198f28a6e3fe2aab.npy. Using default mask.
# Invalid box: tensor([0.3291, 0.3761, 0.3257, 0.3818])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__614_84_best_win_non_rider_jpg.rf.b4fdffb3341ae3c71a833f59c00439f8.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__875_88_best_win_non_rider_jpg.rf.4c5aad8e08120535700dd0e61de21f09.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__599_90_best_win_non_rider_jpg.rf.6aa443934d338a91aef02a43aa196a5b.npy. Using default mask.
# Invalid box: tensor([0.5873, 0.3071, 0.3553, 0.5386])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__981_86_best_win_rider_jpg.rf.f120bababdb87d0d239f162d15ce3c27.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__652_87_best_win_non_rider_jpg.rf.13b32dbe3fe0f4fd553080e6fb21d90c.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__266_87_best_win_rider_jpg.rf.27dbedf4b8b16b2da5122f325d27adfa.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__900_87_best_win_rider_jpg.rf.bee021dadb3478fa87ed4775dbc854ff.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__690_88_best_win_non_rider_jpg.rf.ce38bdf5c05aa2e4b83bafe83604bcda.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__498_90_best_win_non_rider_jpg.rf.0894e12a2fa31f61d2f2998af010c291.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__184_88_best_win_non_rider_jpg.rf.fa8ca1b5937fe994c3e38e857812e961.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__505_86_best_win_rider_jpg.rf.37b355b4724a9550d0190420a120cd9f.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__865_90_best_win_rider_jpg.rf.622f1517489f4e8574d9c8934d074def.npy. Using default mask.
# Invalid box: tensor([0.3650, 0.3594, 0.3323, 0.3707])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__289_84_best_win_rider_jpg.rf.7de53c233b38c318f3ab98e8b37c605f.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__620_87_best_win_rider_jpg.rf.8218f1c6c5ed5251fd92a0203a29bd01.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__363_84_best_win_rider_jpg.rf.d436d7ebffbf28c8ecd8980f18eaeb68.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__530_89_best_win_non_rider_jpg.rf.28ec8a42bbb0b68b2ab87e48f49d24d0.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__576_86_best_win_non_rider_jpg.rf.6354c6eb4c293cf6d648d9ef1f18660e.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__573_88_best_win_rider_jpg.rf.8284e1717f59a3c93d6f178b25af44de.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__590_88_best_win_rider_jpg.rf.10676038fb5e6fa2141d8e83ce72f932.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__555_88_best_win_non_rider_jpg.rf.8a2293da678be105efbf90bfd11395f1.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__784_88_best_win_rider_jpg.rf.f1861bae40a09132615e712661f56096.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__432_72_best_win_rider_jpg.rf.c79168ae1713b9e97aa99b518558751c.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__869_88_best_win_rider_jpg.rf.39cbbfa9b4d7726fdb0009a0c62a0bec.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__868_89_best_win_rider_jpg.rf.a8b05821796f5197bce2d3867dafb573.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__523_84_best_win_non_rider_jpg.rf.6894d7cb716dcd6cb08b31e7a5b54561.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__520_87_best_win_non_rider_jpg.rf.a1d0115a53462062c2a601ef502d1ebf.npy. Using default mask.
# Invalid box: tensor([0.4955, 0.3144, 0.2548, 0.6936])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__261_90_best_win_rider_jpg.rf.a3fc2b0ef07fc0ba6eb2be1b58005d7d.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__606_88_best_win_rider_jpg.rf.4c48a1747abc458a0c14579856d4965e.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__842_87_best_win_non_rider_jpg.rf.de6abaeb5c5128225cb4abbe4ac50eed.npy. Using default mask.
# Invalid box: tensor([0.5511, 0.3066, 0.3288, 0.7051])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__563_92_best_win_non_rider_jpg.rf.a7acb84d7d71ce419e45d21ffc25d55c.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__670_87_best_win_non_rider_jpg.rf.b30a4d1df3945fe2db9fd1defe040dd1.npy. Using default mask.
# Invalid box: tensor([0.6163, 0.2315, 0.3264, 0.7013])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__908_88_best_win_non_rider_jpg.rf.972a81b9257540c86e8cb6bfacf716a1.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__951_86_best_win_non_rider_jpg.rf.530b7391af9e1d3d86f7399f9cf55234.npy. Using default mask.
# Invalid box: tensor([0.5448, 0.3476, 0.5277, 0.3530])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__460_90_best_win_non_rider_jpg.rf.a8aac3b806b9607690f5b06e7dab7548.npy. Using default mask.
# Invalid box: tensor([0.5696, 0.2731, 0.3316, 0.6122])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__967_78_best_win_non_rider_jpg.rf.68b096951888b13eee2132397709195b.npy. Using default mask.
# Invalid box: tensor([0.5532, 0.3014, 0.2865, 0.7420])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__358_89_best_win_non_rider_jpg.rf.355fcbc4048d1dceb82562a9a75baeea.npy. Using default mask.
# Invalid box: tensor([0.4840, 0.2211, 0.1830, 0.5443])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__937_90_best_win_rider_jpg.rf.5041d1388806c508274b536413904220.npy. Using default mask.
# Invalid box: tensor([0.4142, 0.0527, 0.4022, 0.0479])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__662_87_best_win_non_rider_jpg.rf.3b365ab245894ae04b80b28753530e15.npy. Using default mask.
# Invalid box: tensor([0.6317, 0.3110, 0.3524, 0.8102])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__737_87_best_win_non_rider_jpg.rf.753ccb236e4c8d604d5adc9d0cd6fe59.npy. Using default mask.
# Invalid box: tensor([0.4535, 0.3194, 0.1911, 0.7024])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__617_87_best_win_non_rider_jpg.rf.27a93ef2adc983df1efaba49d0ab5234.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__685_84_best_win_non_rider_jpg.rf.b939efda8ce4f1239000089376ab9848.npy. Using default mask.
# Invalid box: tensor([0.5536, 0.2622, 0.2836, 0.6487])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__805_89_best_win_non_rider_jpg.rf.3a95a53c5855a7368cd3e6056c0430af.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__202_89_best_win_rider_jpg.rf.320bb3f1abd5a3aa7c23e673df4aa661.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__684_90_best_win_rider_jpg.rf.e60c9b636462e68c74e31ead658c7805.npy. Using default mask.
# Invalid box: tensor([0.3325, 0.1904, 0.3036, 0.2128])
# Invalid box: tensor([0.6204, 0.2609, 0.5276, 0.2975])
# Invalid box: tensor([0.5578, 0.2131, 0.4872, 0.3189])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__991_82_best_win_rider_jpg.rf.1d8726e39d91d5637da64a59a110423a.npy. Using default mask.
# Invalid box: tensor([0.3060, 0.2850, 0.3003, 0.2813])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__974_89_best_win_non_rider_jpg.rf.e9cdec9fd7fa3fd0ee2a4213f85a7cb5.npy. Using default mask.
# Invalid box: tensor([0.5716, 0.4807, 0.3621, 0.8311])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__493_89_best_win_rider_jpg.rf.57d512c943803a3c0bf9f8bc7d93399a.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__190_90_best_win_non_rider_jpg.rf.2d4bcdbede035e49fdc47ea8dc0333c7.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__781_86_best_win_non_rider_jpg.rf.0711a5719aa56c3d127f5c8c2e653747.npy. Using default mask.
# Invalid box: tensor([0.5247, 0.2767, 0.3013, 0.6086])
# Invalid box: tensor([0.6367, 0.0116, 0.5574, 0.0000])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__699_89_best_win_non_rider_jpg.rf.6d8947b9befff0b28aa8acbb013ee248.npy. Using default mask.
# Invalid box: tensor([0.5476, 0.3603, 0.2732, 0.7626])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__569_89_best_win_rider_jpg.rf.31dad2d3b69b95d43ffab3d3d786bebf.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__895_82_best_win_non_rider_jpg.rf.af5d767e419c2dfd47117d08e22f143f.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__387_90_best_win_rider_jpg.rf.d7351af8304f32d6ef90c67e005799db.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__734_88_best_win_rider_jpg.rf.e6e3e89e49f3252b8c3ad44c1ed84d5a.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__503_88_best_win_rider_jpg.rf.fb9a16da622c5efaa65f3c4fcecfb2b7.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__963_89_best_win_non_rider_jpg.rf.86f3e38e9956b3439c666b11fdd382f7.npy. Using default mask.
# Invalid box: tensor([0.5677, 0.2331, 0.2972, 0.5414])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__396_81_best_win_rider_jpg.rf.546ae26fe12019e9a9f1c8e4be768a1c.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__640_88_best_win_rider_jpg.rf.24ed073b1d574c72defd0cffc7ce7cb4.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__751_89_best_win_non_rider_jpg.rf.48781cb3fadafec3e3d75c9a78a858ab.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__803_89_best_win_non_rider_jpg.rf.332821776f4e1137366ab07d1e91a23f.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__189_89_best_win_rider_jpg.rf.65c07f3cac684ca1bbbbcf6e7cfe3689.npy. Using default mask.
# Invalid box: tensor([0.5266, 0.4760, 0.3733, 0.3103])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__251_88_best_win_rider_jpg.rf.b97b29351294546c0567498e7f7814e6.npy. Using default mask.
# Invalid box: tensor([0.2980, 0.1675, 0.2762, 0.1677])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__702_90_best_win_non_rider_jpg.rf.ca301a9313cce997fc962f369ac03633.npy. Using default mask.
# Invalid box: tensor([0.3590, 0.6240, 0.5991, 0.1802])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__654_90_best_win_non_rider_jpg.rf.667473819ab524141068d4aaaff1d028.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__280_85_best_win_rider_jpg.rf.73116de98898ad088468c2a5f9b71343.npy. Using default mask.
# ...
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__674_89_best_win_non_rider_jpg.rf.16e035e8144a006fc28b0ab9a301a320.npy. Using default mask.
# Invalid box: tensor([0.5347, 0.3466, 0.3638, 0.5918])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__597_86_best_win_non_rider_jpg.rf.5e7e531b71f5f8158fa0640a14461b5b.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__313_87_best_win_rider_jpg.rf.8db83a915d67a6d556f96d7275e44df1.npy. Using default mask.
# Invalid box: tensor([0.5813, 0.3311, 0.3232, 0.7111])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__221_85_best_win_rider_jpg.rf.89aa7b6b68bd9b5cb9c486fe18bee765.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__463_87_best_win_rider_jpg.rf.cbcd8658b80b595df12816719f517ed2.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__862_88_best_win_non_rider_jpg.rf.e45899371855b11237d4b100f5f08c0d.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__326_86_best_win_non_rider_jpg.rf.320b3d960b499d349481dc971d189017.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__185_88_best_win_non_rider_jpg.rf.8f9ec337e1f0ddd1d26d69e0b2e75d66.npy. Using default mask.
# Invalid box: tensor([0.6488, 0.2538, 0.5694, 0.2671])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__527_83_best_win_non_rider_jpg.rf.40d0acb5ca234d24729a92ace9871eee.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__870_90_best_win_rider_jpg.rf.bcb3dbaa9430f6e37cad61100e8ffe2e.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__561_90_best_win_non_rider_jpg.rf.07f9869b1661f450fc7147e8ebbaba70.npy. Using default mask.
# Invalid box: tensor([0.5445, 0.3907, 0.3236, 0.7327])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__896_87_best_win_rider_jpg.rf.d3782711c2ecee1bf6315df8896dbca3.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__792_89_best_win_non_rider_jpg.rf.65183b60ce8060cd4bcd0091363121d2.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__337_90_best_win_non_rider_jpg.rf.d5a245dac16fc6a2256b44df927af89b.npy. Using default mask.
# Invalid box: tensor([0.5782, 0.4048, 0.2664, 0.7787])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__712_88_best_win_non_rider_jpg.rf.b737d6841b4e715c77577f193e4ef65a.npy. Using default mask.
# Invalid box: tensor([0.4744, 0.1726, 0.2058, 0.5611])
# Invalid box: tensor([0.5600, 0.3954, 0.4003, 0.6323])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__362_87_best_win_non_rider_jpg.rf.68512cea934d9956483b4ac31bb0377b.npy. Using default mask.
# Invalid box: tensor([0.5323, 0.3367, 0.3380, 0.6539])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__743_83_best_win_rider_jpg.rf.b4b46edfd919d46a25115e62b155007c.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__766_82_best_win_non_rider_jpg.rf.37f49b785002b658cb979882d493c524.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__301_79_best_win_non_rider_jpg.rf.552d6a42f9ea815f6521fa0e8f437cab.npy. Using default mask.
# Invalid box: tensor([0.6482, 0.2561, 0.5372, 0.2988])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__434_85_best_win_non_rider_jpg.rf.9b796033888d937d87af9cdd6900e685.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__782_86_best_win_rider_jpg.rf.83f62c23626e55c860b4ad5b69d84b7d.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__549_87_best_win_non_rider_jpg.rf.d5014803f61c08554b6c6b55fb08849c.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__657_85_best_win_non_rider_jpg.rf.e1dd6c32fea6c4d6ebb51758dc8bd627.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__603_88_best_win_non_rider_jpg.rf.6aef2708646eb349a06b74b47c989439.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__945_89_best_win_non_rider_jpg.rf.e57a6a24bcd30f699259314e72c4a27a.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__876_82_best_win_non_rider_jpg.rf.b4b6e42b954268c01eb0f7e6e1374a80.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__849_88_best_win_non_rider_jpg.rf.71bf62bc33ae32e6a34d76509bc71364.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__407_89_best_win_non_rider_jpg.rf.a06582eb12069ac2b631cb6f694c7f26.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__365_89_best_win_rider_jpg.rf.540d2fdecd84f079e6d22e3290d2dc03.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__674_89_best_win_rider_jpg.rf.d80a7d98756a02a94097c1e4a075401d.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__384_86_best_win_rider_jpg.rf.ec00debbb4ee59d987edcf9c15242aaf.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__673_90_best_win_rider_jpg.rf.37abd514989cd802ff1ab8782c3a1af1.npy. Using default mask.
# Invalid box: tensor([0.6446, 0.1053, 0.5574, 0.1125])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__180_88_best_win_non_rider_jpg.rf.ec87cf638d7546c83a522fb5171fbda3.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__388_86_best_win_non_rider_jpg.rf.d508abd7bb341c578d41585e49e314f2.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__872_81_best_win_non_rider_jpg.rf.b3277f65ada3d65361663954977309b3.npy. Using default mask.
# Invalid box: tensor([0.4143, 0.6976, 0.7354, 0.3271])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__588_89_best_win_rider_jpg.rf.f3c7a39bf5fc6b7c92edc83006f55673.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__947_89_best_win_rider_jpg.rf.5d06199ca6f810cee88d2fae84df3362.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__490_90_best_win_rider_jpg.rf.fcd94508faed21e178eef874489f1844.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__707_88_best_win_rider_jpg.rf.df141f1548acb8965762fc296915968a.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__295_87_best_win_non_rider_jpg.rf.c8d0e23818d0c9d98db153ee78c46380.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__252_90_best_win_non_rider_jpg.rf.d4f7781911d1ee921a8457d78df01063.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__304_87_best_win_non_rider_jpg.rf.2174626262a583dec3b83d76cd194951.npy. Using default mask.
# Invalid box: tensor([0.6133, 0.2127, 0.5729, 0.2000])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__196_90_best_win_rider_jpg.rf.d3b653c79ad149172ba80369c5818948.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__468_88_best_win_non_rider_jpg.rf.112ead6a52172e0e42052201f6ad590a.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__852_88_best_win_non_rider_jpg.rf.152a411eba0623be1b90561f325efbdd.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__736_85_best_win_non_rider_jpg.rf.bd36f9b271ffa12de5629746c04ac40e.npy. Using default mask.
# Invalid box: tensor([0.4769, 0.1865, 0.2419, 0.5894])
# Invalid box: tensor([0.4477, 0.4020, 0.2518, 0.6129])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__893_86_best_win_non_rider_jpg.rf.7835e56d86808dc206bf2686fc61b9c0.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__969_90_best_win_rider_jpg.rf.b0e596298d3f15cca76a442ac7eed2e2.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__287_88_best_win_rider_jpg.rf.b347b50371a295415f53c0b89d8cf382.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__205_89_best_win_rider_jpg.rf.5997adcaae1849ccf27d1ed2bdf4637a.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__356_87_best_win_non_rider_jpg.rf.0d682606085ddfdbf533569eb0bf1cb5.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__544_91_best_win_non_rider_jpg.rf.54c0d0ae96a1a5541fe18d08dc48c318.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__297_89_best_win_non_rider_jpg.rf.2777aad89d0b5fc28bcc126b3ef58e42.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__573_88_best_win_non_rider_jpg.rf.483741718044b935cf01396dcf00ed0f.npy. Using default mask.
# Invalid box: tensor([0.5488, 0.2599, 0.2667, 0.7019])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__947_89_best_win_non_rider_jpg.rf.d0f6e887885e8a0f2d2d1e7782a9ec6a.npy. Using default mask.
# Invalid box: tensor([0.2585, 0.0390, 0.2336, 0.0742])
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__988_87_best_win_rider_jpg.rf.d6a47cc2e892c2166b7aa773435cd32c.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__933_85_best_win_rider_jpg.rf.f1d0777b3773f85ca899fa6f47e90322.npy. Using default mask.
# Warning: Mask file not found: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/train/images/Car__552_88_best_win_rider_jpg.rf.32758c97c14221747034b7127e7694c4.npy. Using default mask.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-4c17913472cf> in <cell line: 117>()
#     118     model.train()
#     119     epoch_loss = 0
# --> 120     for images, targets in train_dataloader:
#     121         images = list(image.to(device) for image in images)
#     122         targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     629                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630                 self._reset()  # type: ignore[call-arg]
# --> 631             data = self._next_data()
#     632             self._num_yielded += 1
#     633             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     673     def _next_data(self):
#     674         index = self._next_index()  # may raise StopIteration
# --> 675         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676         if self._pin_memory:
#     677             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# <ipython-input-21-4c17913472cf> in __getitem__(self, idx)
#      31         # Load mask with default if not found
#      32         if os.path.exists(mask_path):
# ---> 33             mask = np.load(mask_path)
#      34             mask = torch.tensor(mask, dtype=torch.uint8)
#      35         else:
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     454                                           max_header_size=max_header_size)
#     455             else:
# --> 456                 return format.read_array(fid, allow_pickle=allow_pickle,
#     457                                          pickle_kwargs=pickle_kwargs,
#     458                                          max_header_size=max_header_size)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs, max_header_size)
#     807         if isfileobj(fp):
#     808             # We can use the fast fromfile() function.
# --> 809             array = numpy.fromfile(fp, dtype=dtype, count=count)
#     810         else:
#     811             # This is not a real file. We have to read it the
#
# KeyboardInterrupt:

# %%
# import numpy as np
# from torchvision.ops import box_iou

# def evaluate_model(model, dataloader, device):
#     model.eval()
#     all_predictions = []
#     all_targets = []

#     with torch.no_grad():
#         for images, targets in dataloader:
#             images = list(image.to(device) for image in images)
#             targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

#             outputs = model(images)
#             all_predictions.extend(outputs)
#             all_targets.extend(targets)

#     return all_predictions, all_targets

# def compute_iou(box1, box2):
#     return box_iou(box1.unsqueeze(0), box2.unsqueeze(0)).item()

# def compute_map(predictions, targets, iou_threshold=0.5):
#     average_precisions = []

#     for prediction, target in zip(predictions, targets):
#         pred_boxes = prediction['boxes'].cpu().numpy()
#         pred_scores = prediction['scores'].cpu().numpy()
#         target_boxes = target['boxes'].cpu().numpy()

#         num_gt_boxes = len(target_boxes)
#         num_pred_boxes = len(pred_boxes)

#         if num_gt_boxes == 0:
#             continue

#         tp = np.zeros(num_pred_boxes)
#         fp = np.zeros(num_pred_boxes)

#         for i, pred_box in enumerate(pred_boxes):
#             iou_max = 0.0
#             for gt_box in target_boxes:
#                 iou = compute_iou(torch.tensor(pred_box), torch.tensor(gt_box))
#                 if iou > iou_max:
#                     iou_max = iou

#             if iou_max > iou_threshold:
#                 tp[i] = 1
#             else:
#                 fp[i] = 1

#         fp_cumsum = np.cumsum(fp)
#         tp_cumsum = np.cumsum(tp)
#         recalls = tp_cumsum / num_gt_boxes
#         precisions = tp_cumsum / (tp_cumsum + fp_cumsum)

#         recall_thresholds = np.linspace(0, 1, 11)
#         precision_interpolated = np.zeros_like(recall_thresholds)

#         for i, threshold in enumerate(recall_thresholds):
#             precisions_above_threshold = precisions[recalls >= threshold]
#             if precisions_above_threshold.size > 0:
#                 precision_interpolated[i] = precisions_above_threshold.max()
#             else:
#                 precision_interpolated[i] = 0.0

#         average_precision = precision_interpolated.mean()
#         average_precisions.append(average_precision)

#     mean_average_precision = np.mean(average_precisions) if average_precisions else 0.0
#     return mean_average_precision

# def visualize_results(images, targets, outputs):
#     for i in range(len(images)):
#         image = images[i].permute(1, 2, 0).cpu().numpy()
#         target = targets[i]
#         output = outputs[i]

#         plt.figure(figsize=(15, 5))

#         plt.subplot(1, 3, 1)
#         plt.imshow(image)
#         plt.title('Image')

#         plt.subplot(1, 3, 2)
#         mask = target['masks'][0].cpu().numpy()
#         plt.imshow(mask, cmap='gray')
#         plt.title('Ground Truth Mask')

#         plt.subplot(1, 3, 3)
#         if output['masks'].shape[0] > 0:
#             pred_mask = output['masks'][0, 0].cpu().numpy()
#         else:
#             pred_mask = np.zeros_like(mask)
#         plt.imshow(pred_mask, cmap='gray')
#         plt.title(f'Predicted Mask')

#         plt.show()

# # Evaluation
# model.eval()
# predictions, targets = evaluate_model(model, val_dataloader, device)
# mAP = compute_map(predictions, targets)
# print(f"Mean Average Precision (mAP): {mAP:.2f}")

# # Visualization
# images, targets = next(iter(val_dataloader))
# images = list(image.to(device) for image in images)
# with torch.no_grad():
#     outputs = model(images)

# visualize_results(images, targets, outputs)

# %%
import os
from PIL import Image
from torchvision.transforms import functional as F
from torch.utils.data import Dataset

class TestDataset(Dataset):
    def __init__(self, image_dir, transform=None):
        self.image_dir = image_dir
        self.transform = transform
        self.image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        image_path = os.path.join(self.image_dir, self.image_files[idx])
        image = Image.open(image_path).convert("RGB")

        if self.transform:
            image = self.transform(image)

        return image, self.image_files[idx]

from torchvision.transforms import ToTensor, Resize, Compose

transform = Compose([
    Resize((800, 800)),  # Adjust size as needed
    ToTensor()
])


from torch.utils.data import DataLoader

# Define test dataset and dataloader
test_dataset = TestDataset('/content/drive/MyDrive/SeatBelt_project/DATA/testing', transform=transform)
test_dataloader = DataLoader(test_dataset, batch_size=4, shuffle=False)

# Load the trained model
model.load_state_dict(torch.load('/content/drive/MyDrive/mask_rcnn_seatbelt.pth'))
model.to(device)
model.eval()

# Run predictions
def predict_on_test_set(model, dataloader, device):
    predictions = []
    image_files = []

    with torch.no_grad():
        for images, files in dataloader:
            images = list(image.to(device) for image in images)
            outputs = model(images)
            predictions.extend(outputs)
            image_files.extend(files)

    return predictions, image_files

predictions, image_files = predict_on_test_set(model, test_dataloader, device)


def visualize_test_results(images, predictions, image_files):
    for i in range(len(images)):
        image = images[i].permute(1, 2, 0).cpu().numpy()
        image_file = image_files[i]

        plt.figure(figsize=(10, 10))
        plt.imshow(image)
        plt.title(f'Image: {image_file}')

        if predictions[i]['masks'].shape[0] > 0:
            pred_mask = predictions[i]['masks'][0, 0].cpu().numpy()
            plt.imshow(pred_mask, cmap='jet', alpha=0.5)  # Overlay mask
        plt.show()

# Visualize results
images, _ = zip(*[test_dataset[idx] for idx in range(len(test_dataset))])
images = [transform(img).unsqueeze(0).to(device) for img in images]
images = [img.squeeze(0) for img in images]
visualize_test_results(images, predictions, image_files)
