# %% [markdown]
# #GPU INFERENCE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Wed Apr 10 09:17:16 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# %pwd
# %cd drive/MyDrive
# %pwd
# Out:
# /content/drive/MyDrive
# '/content/drive/MyDrive'

# %%
# %cd /content/drive/MyDrive/ultralytics
# !pip install -e . -q
# Out:
# /content/drive/MyDrive/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for ultralytics (pyproject.toml) ... done

# %%
from IPython import display
display.clear_output()

import sys
sys.path.append('/content/drive/MyDrive/ultralytics')

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /root/.config/Ultralytics
# %ls
# Out:
# /root/.config/Ultralytics
# settings.yaml

# %%
# View the original contents of the YAML file
# !cat settings.yaml

# Modify the YAML file to change the datasets_dir
# !sed -i 's|datasets_dir: /content/drive/MyDrive/datasets|datasets_dir: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/|g' settings.yaml

# Verify the changes
# !cat settings.yaml
# Out:
# settings_version: 0.0.4
# datasets_dir: /content/drive/MyDrive/datasets
# weights_dir: /content/drive/MyDrive/ultralytics/weights
# runs_dir: /content/drive/MyDrive/ultralytics/runs
# uuid: 569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb
# sync: true
# api_key: ''
# openai_api_key: ''
# clearml: true
# comet: true
# dvc: true
# hub: true
# mlflow: true
# neptune: true
# raytune: true
# tensorboard: true
# wandb: true
# settings_version: 0.0.4
# datasets_dir: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/
# weights_dir: /content/drive/MyDrive/ultralytics/weights
# runs_dir: /content/drive/MyDrive/ultralytics/runs
# uuid: 569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb
# sync: true
# api_key: ''
# openai_api_key: ''
# clearml: true
# comet: true
# dvc: true
# hub: true
# mlflow: true
# neptune: true
# raytune: true
# tensorboard: true
# wandb: true

# %%
run_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs"
# %cd {run_path}
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs

# %%
dataset_path = "/content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1"

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/Default_run_25"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/Default_run_25
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 88.1MB/s]
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:11<00:00,  1.43it/s]
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/Default_run_100"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/Default_run_100
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [00:07<00:00,  2.15it/s]
#                    all        246        134      0.828      0.813      0.852      0.552
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT32"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT32
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:06<00:00,  1.14it/s]
#                    all        246        134      0.822      0.843      0.869      0.582
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT64"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT64
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:09<00:00,  2.49s/it]
#                    all        246        134      0.821      0.821      0.862       0.56
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP50_BT128"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP50_BT128
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.04s/it]
#                    all        246        134      0.868      0.784      0.866      0.584
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT64_FR3"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT64_FR3
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:09<00:00,  2.32s/it]
#                    all        246        134      0.773      0.858      0.851      0.557
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/Run_ep100_BT64_FR5"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/Run_ep100_BT64_FR5
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:09<00:00,  2.49s/it]
#                    all        246        134      0.825      0.843      0.865      0.561
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_OPAdam_LR0.001"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_OPAdam_LR0.001
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:08<00:00,  2.16s/it]
#                    all        246        134      0.857      0.847      0.877      0.568
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/Run_OPSGD_LR0.001"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/Run_OPSGD_LR0.001
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:09<00:00,  2.43s/it]
#                    all        246        134      0.827      0.854      0.875      0.553
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_OPP_SEG"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=segment mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_OPP_SEG
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3258259 parameters, 0 gradients, 12.0 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 4/4 [00:11<00:00,  2.94s/it]
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_OPP_SEG"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=segment mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP

# %% [markdown]
# #CPU INFERENCE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pwd
# %cd drive/MyDrive
# %pwd
# Out:
# /content/drive/MyDrive
# '/content/drive/MyDrive'

# %%
# %cd /content/drive/MyDrive/ultralytics
# !pip install -e . -q
# Out:
# /content/drive/MyDrive/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for ultralytics (pyproject.toml) ... done

# %%
from IPython import display
display.clear_output()

import sys
sys.path.append('/content/drive/MyDrive/ultralytics')

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.0/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /root/.config/Ultralytics
# %ls
# Out:
# /root/.config/Ultralytics
# settings.yaml

# %%
# View the original contents of the YAML file
# !cat settings.yaml

# Modify the YAML file to change the datasets_dir
# !sed -i 's|datasets_dir: /content/drive/MyDrive/datasets|datasets_dir: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/|g' settings.yaml

# Verify the changes
# !cat settings.yaml
# Out:
# settings_version: 0.0.4
# datasets_dir: /content/drive/MyDrive/datasets
# weights_dir: /content/drive/MyDrive/ultralytics/weights
# runs_dir: /content/drive/MyDrive/ultralytics/runs
# uuid: 569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb
# sync: true
# api_key: ''
# openai_api_key: ''
# clearml: true
# comet: true
# dvc: true
# hub: true
# mlflow: true
# neptune: true
# raytune: true
# tensorboard: true
# wandb: true
# settings_version: 0.0.4
# datasets_dir: /content/drive/MyDrive/SeatBelt_project/Robo_datasets/
# weights_dir: /content/drive/MyDrive/ultralytics/weights
# runs_dir: /content/drive/MyDrive/ultralytics/runs
# uuid: 569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb
# sync: true
# api_key: ''
# openai_api_key: ''
# clearml: true
# comet: true
# dvc: true
# hub: true
# mlflow: true
# neptune: true
# raytune: true
# tensorboard: true
# wandb: true

# %%
run_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs"
# %cd {run_path}
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs

# %%
dataset_path = "/content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1"

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/Default_run_25"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP_cpu batch=16
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/Default_run_25
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [03:04<00:00, 11.52s/it]
#                    all        246        134       0.86      0.824      0.871      0.561
# Speed: 5.8ms preprocess, 719.6ms inference, 0.0ms loss, 0.3ms postprocess per image
# Saving /content/drive/MyDrive/SeatBelt_project/All_Runs/Default_run_25/test_mAP_cpu2/predictions.json...
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/Default_run_100"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP_cpu batch=16
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/Default_run_100
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 16/16 [03:12<00:00, 12.06s/it]
#                    all        246        134      0.828      0.813      0.852      0.552
# Speed: 7.4ms preprocess, 756.0ms inference, 0.0ms loss, 0.3ms postprocess per image
# Saving /content/drive/MyDrive/SeatBelt_project/All_Runs/Default_run_100/test_mAP_cpu/predictions.json...
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT32"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP_cpu batch=32
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT32
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [01:23<00:00, 10.45s/it]
#                    all        246        134      0.822      0.843      0.869      0.582
# Speed: 6.7ms preprocess, 307.3ms inference, 0.0ms loss, 0.5ms postprocess per image
# Saving /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT32/test_mAP_cpu/predictions.json...
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT64"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP_cpu batch=64
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT64
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [01:32<00:00, 23.12s/it]
#                    all        246        134      0.821      0.821      0.862       0.56
# Speed: 6.8ms preprocess, 347.7ms inference, 0.0ms loss, 0.4ms postprocess per image
# Saving /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT64/test_mAP_cpu/predictions.json...
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP50_BT128"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP_cpu batch=128
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP50_BT128
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [01:32<00:00, 46.03s/it]
#                    all        246        134      0.868      0.784      0.866      0.584
# Speed: 7.4ms preprocess, 344.3ms inference, 0.0ms loss, 0.4ms postprocess per image
# Saving /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP50_BT128/test_mAP_cpu/predictions.json...
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT64_FR3"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP_cpu batch=64 freeze=3
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT64_FR3
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [01:27<00:00, 21.89s/it]
#                    all        246        134      0.773      0.858      0.851      0.557
# Speed: 6.3ms preprocess, 328.1ms inference, 0.0ms loss, 0.4ms postprocess per image
# Saving /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_EP100_BT64_FR3/test_mAP_cpu/predictions.json...
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/Run_ep100_BT64_FR5"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP_cpu batch=64 freeze=5
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/Run_ep100_BT64_FR5
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [01:23<00:00, 20.98s/it]
#                    all        246        134      0.825      0.843      0.865      0.561
# Speed: 6.8ms preprocess, 309.2ms inference, 0.0ms loss, 0.5ms postprocess per image
# Saving /content/drive/MyDrive/SeatBelt_project/All_Runs/Run_ep100_BT64_FR5/test_mAP_cpu/predictions.json...
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_OPAdam_LR0.001"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP_cpu batch=64
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_OPAdam_LR0.001
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [01:22<00:00, 20.67s/it]
#                    all        246        134      0.857      0.847      0.877      0.568
# Speed: 6.1ms preprocess, 308.9ms inference, 0.0ms loss, 0.4ms postprocess per image
# Saving /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_OPAdam_LR0.001/test_mAP_cpu/predictions.json...
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/Run_OPSGD_LR0.001"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP_cpu batch=64
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/Run_OPSGD_LR0.001
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [01:28<00:00, 22.02s/it]
#                    all        246        134      0.827      0.854      0.875      0.553
# Speed: 6.1ms preprocess, 328.0ms inference, 0.0ms loss, 0.4ms postprocess per image
# Saving /content/drive/MyDrive/SeatBelt_project/All_Runs/Run_OPSGD_LR0.001/test_mAP_cpu/predictions.json...
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_OPP_SEG"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=segment mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP_cpu batch=64
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_OPP_SEG
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n-seg summary (fused): 195 layers, 3258259 parameters, 0 gradients, 12.0 GFLOPs
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 4/4 [02:06<00:00, 31.60s/it]
#                    all        246        134      0.776      0.851      0.847      0.552      0.905      0.782      0.862      0.453
# Speed: 7.5ms preprocess, 468.7ms inference, 0.0ms loss, 0.6ms postprocess per image
# ...

# %%
project_path = "/content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_yolo_ghost"

yaml_path = "/content/drive/MyDrive/SeatBelt_project/custom.yaml"

# %cd {project_path}

# !yolo cfg={yaml_path} task=detect mode=val model={project_path}/train/weights/best.pt  data={dataset_path}/data.yaml project={project_path} name=test_mAP_cpu batch=64
# Out:
# /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_yolo_ghost
# Overriding /content/drive/MyDrive/ultralytics/ultralytics/cfg/default.yaml with /content/drive/MyDrive/SeatBelt_project/custom.yaml
# Ultralytics YOLOv8.1.42 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8-ghost summary (fused): 312 layers, 1714271 parameters, 0 gradients, 5.0 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 16.8MB/s]
# val: Scanning /content/drive/MyDrive/SeatBelt_project/Robo_datasets/SeatBelt-1/test/labels.cache... 246 images, 112 backgrounds, 0 corrupt: 100% 246/246 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [01:26<00:00, 21.68s/it]
#                    all        246        134      0.821      0.888      0.873       0.61
# Speed: 7.7ms preprocess, 309.2ms inference, 0.0ms loss, 0.7ms postprocess per image
# Saving /content/drive/MyDrive/SeatBelt_project/All_Runs/RUN_yolo_ghost/test_mAP_cpu/predictions.json...
# ...
